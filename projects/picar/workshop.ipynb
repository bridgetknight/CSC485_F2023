# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
def nothing(x):
    pass

# %%
def detect_edges(img):
    # filter out white lines
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    #show_img("hsv", hsv)

    # threshold for counting a pixel as white
    sensitivity = 30
    lower_white = np.array([98, 0, 255-sensitivity])
    upper_white = np.array([179, 179, 255])

    mask = cv2.inRange(hsv, lower_white, upper_white)

    # detect edges
    edges = cv2.Canny(mask, 200, 400)
    #show_img("edges", edges)
    #matplotlib.image.imsave("canny_result.png", edges)
    plt.imshow(edges)
    
    return edges, mask

# %%
def detect_stop_line(img):
    # filter out white lines
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    #show_img("hsv", hsv)

    # threshold for counting a pixel as white
    sensitivity = 30
    lower_white = np.array([52, 77, 140])
    upper_white = np.array([179, 179, 255])

    mask = cv2.inRange(hsv, lower_white, upper_white)

    # detect edges
    edges = cv2.Canny(mask, 200, 400)
    #show_img("edges", edges)
    #matplotlib.image.imsave("canny_result.png", edges)
    plt.imshow(edges)
    
    return edges, mask

# %%
file = "test_data/center_lane.jpg"
img = cv2.imread(file)
m = detect_stop_line(img)
plt.imshow(m[0])

# %%
plt.imshow(m[1])

# %%
plt.imshow(img)

# %%
# Create a window
cv2.namedWindow('image')

# create trackbars for color change
cv2.createTrackbar('HMin','image',0,179,nothing) # Hue is from 0-179 for Opencv
cv2.createTrackbar('SMin','image',0,255,nothing)
cv2.createTrackbar('VMin','image',0,255,nothing)
cv2.createTrackbar('HMax','image',0,179,nothing)
cv2.createTrackbar('SMax','image',0,255,nothing)
cv2.createTrackbar('VMax','image',0,255,nothing)

# Set default value for MAX HSV trackbars.
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize to check if HSV min/max value changes
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

output = img
wait_time = 33

while(1):

    # get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin','image')
    sMin = cv2.getTrackbarPos('SMin','image')
    vMin = cv2.getTrackbarPos('VMin','image')

    hMax = cv2.getTrackbarPos('HMax','image')
    sMax = cv2.getTrackbarPos('SMax','image')
    vMax = cv2.getTrackbarPos('VMax','image')

    # Set minimum and max HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Create HSV Image and threshold into a range.
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    output = cv2.bitwise_and(img,img, mask= mask)

    # Print if there is a change in HSV value
    if( (phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display output image
    cv2.imshow('image',output)

    # Wait longer to prevent freeze for videos.
    if cv2.waitKey(wait_time) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 16 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 5, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 8, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 15, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 17, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 19, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 20, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 28, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 48, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 51, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 53, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 56, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 57, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 58, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 59, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 60, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 63, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 64, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 65, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 67, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 68, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 69, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 70, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 72, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 73, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 75, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 76, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 78, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 79, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 80, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 81, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 83, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 84, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 85, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 86, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 88, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 90, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 91, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 93, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 92, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 90, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 88, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 86, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 85, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 84, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 83, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 81, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 80, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 79, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 78, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 5), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 9), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 11), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 15), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 16), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 17), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 19), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 21), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 23), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 25), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 27), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 28), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 30), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 31), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 32), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 33), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 34), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 39), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 41), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 44), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 50), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 54), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 58), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 59), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 62), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 64), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 67), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 69), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 70), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 65), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 52), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 25), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 9), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 15), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 39), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 69), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 91), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 102), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 105), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 111), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 112), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 115), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 120), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 124), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 128), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 132), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 135), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 140), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 141), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 143), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 144), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 146), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 159), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 174), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 191), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 204), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 212), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 219), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 220), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 218), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 201), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 167), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 142), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 135), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 137), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 138), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 139), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 138), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 134), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 130), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 31 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 40 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 47 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 51 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 126), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 122), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 119), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 118), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 117), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 115), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 113), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 111), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 107), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 104), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 102), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 100), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 99), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 100), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 106), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 111), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 116), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 120), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 122), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 124), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 126), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 128), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 129), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 130), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 128), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 117), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 107), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 103), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 93), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 90), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 87), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 81), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 69), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 57), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 42), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 33), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 25), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 20), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 18), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 15), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 11), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 9), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 8), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 7), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 6), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 8), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 22), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 49), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 54), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 58), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 59), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 63), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 66), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 69), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 76), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 81), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 86), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 90), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 97), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 100), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 103), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 106), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 109), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 111), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 114), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 116), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 118), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 120), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 121), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 123), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 126), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 128), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 129), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 130), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 132), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 133), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 135), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 137), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 138), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 139), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 140), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 141), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 142), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 143), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 145), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 147), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 149), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 150), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 151), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 152), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 153), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 154), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 155), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 154), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 152), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 151), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 150), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 149), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 148), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 147), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 146), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 144), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 142), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 141), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 140), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 139), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 77, vMin = 140), (hMax = 179 , sMax = 255, vMax = 255)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26656/258243919.py in <module>
#      25
#      26     # get current positions of all trackbars
# ---> 27     hMin = cv2.getTrackbarPos('HMin','image')
#      28     sMin = cv2.getTrackbarPos('SMin','image')
#      29     vMin = cv2.getTrackbarPos('VMin','image')
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2561: error: (-27:Null pointer) NULL window: 'image' in function 'cvGetTrackbarPos'
